# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('distributions.csv')
data
# Out:
#          1             2             3             4             5  \
# 0    0.001  3.792100e+01  3.792100e+01  3.792100e+01  3.792100e+01
# 1    0.002  1.937100e+01  1.937100e+01  1.937100e+01  1.937100e+01
# 2    0.003  1.302000e+01  1.302000e+01  1.302000e+01  1.302000e+01
# 3    0.004  9.791700e+00  9.791700e+00  9.791700e+00  9.791700e+00
# 4    0.005  7.831500e+00  7.831500e+00  7.831500e+00  7.831500e+00
# ..     ...           ...           ...           ...           ...
# 994  0.995  4.661500e-26  4.661500e-26  4.661500e-26  4.661500e-26
# 995  0.996  4.518700e-27  4.518700e-27  4.518700e-27  4.518700e-27
# 996  0.997  2.230900e-28  2.230900e-28  2.230900e-28  2.230900e-28
# 997  0.998  3.215300e-30  3.215300e-30  3.215300e-30  3.215300e-30
# 998  0.999  2.290000e-33  2.290000e-33  2.290000e-33  2.290000e-33
#
#                 6              7             8             9            10  \
# 0    3.792100e+01   1.615000e+02  6.867200e+01  3.792100e+01  2.027800e+01
# ...

# %%
fig, axs = plt.subplots(1, 3)
fig.set_figheight(3)
fig.set_figwidth(10)

#axs[0].plot(data['1'], data['2'], color=(0.0, 0.0, 0.0))
#axs[0].plot(data['1'], data['3'], color=(0.3, 0.3, 0.3))
axs[0].plot(data['1'], data['4'], color=(0.55, 0.55, 0.55))
#axs[0].plot(data['1'], data['5'], color=(0.75, 0.75, 0.75))
#axs[0].plot(data['1'], data['6'], color=(0.9, 0.9, 0.9))
#axs[0].set_title('Distributions')
axs[0].set(xlabel='x (log scale)',ylabel='f(x)')
axs[0].set_xscale('log')
axs[0].set_ylim([0, 2])

axs[1].plot(data['1'], data['7'], color=(0.0, 0.0, 0.0))
axs[1].plot(data['1'], data['8'], color=(0.3, 0.3, 0.3))
axs[1].plot(data['1'], data['9'], color=(0.55, 0.55, 0.55))
axs[1].plot(data['1'], data['10'], color=(0.75, 0.75, 0.75))
axs[1].plot(data['1'], data['11'], color=(0.9, 0.9, 0.9))
#axs[1].set_title('Distributions')
axs[1].set(xlabel='x (log scale)',ylabel='f(x)')
axs[1].set_xscale('log')
axs[1].set_ylim([0, 2])

axs[2].plot(data['1'], data['12'], color=(0.0, 0.0, 0.0))
axs[2].plot(data['1'], data['13'], color=(0.3, 0.3, 0.3))
axs[2].plot(data['1'], data['14'], color=(0.55, 0.55, 0.55))
axs[2].plot(data['1'], data['15'], color=(0.75, 0.75, 0.75))
axs[2].plot(data['1'], data['16'], color=(0.9, 0.9, 0.9))
#axs[2].set_title('Distributions')
axs[2].set(xlabel='x (log scale)',ylabel='f(x)')
axs[2].set_xscale('log')
axs[2].set_ylim([0, 2])

for ax in axs.flat:
    ax.label_outer();
