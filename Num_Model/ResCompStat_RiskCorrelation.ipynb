# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('2corVar.csv')
data['1'] = data['1']*100
data['6'] = data['6']*100
data['11'] = data['11']*100
data['16'] = data['16']*100
data['21'] = data['21']*100
data['3'] = data['3']*100
data['8'] = data['8']*100
data['13'] = data['13']*100
data['18'] = data['18']*100
data['23'] = data['23']*100
data['4'] = data['4']*100
data['9'] = data['9']*100
data['14'] = data['14']*100
data['19'] = data['19']*100
data['24'] = data['24']*100
data['5'] = data['5']*100
data['10'] = data['10']*100
data['15'] = data['15']*100
data['20'] = data['20']*100
data['25'] = data['25']*100
data
# Out:
#          1          2        3        4       5       6          7        8  \
# 0    0.001   0.002093  1.84870   96.326  93.866   0.001   0.005964  6.43320
# 1    0.005   0.010539  1.84680   96.332  93.871   0.005   0.031181  6.41450
# 2    0.010   0.021128  1.84460   96.350  93.876   0.010   0.063435  6.39370
# 3    0.020   0.042327  1.84070   96.375  93.885   0.020   0.128870  6.35630
# 4    0.040   0.084744  1.83370   96.423  93.899   0.040   0.261450  6.28990
# 5    0.070   0.148350  1.82430   96.490  93.917   0.070   0.462350  6.20200
# 6    0.100   0.211930  1.81560   96.558  93.930   0.100   0.664700  6.12290
# 7    0.150   0.317850  1.80230   96.667  93.949   0.150   1.004000  6.00360
# 8    0.200   0.423710  1.78990   96.771  93.963   0.200   1.345400  5.89560
# 9    0.250   0.529540  1.77830   96.875  93.973   0.250   1.688300  5.79580
# 10   0.300   0.635330  1.76720   96.973  93.981   0.300   2.032400  5.70260
# ...

# %%
fig, axs = plt.subplots(3, 2)
fig.set_figheight(12)
fig.set_figwidth(8)

axs[0, 0].plot(data['1'], data['3'], color=(0.0, 0.0, 0.0))
axs[0, 0].plot(data['6'], data['8'], color=(0.3, 0.3, 0.3))
axs[0, 0].plot(data['11'], data['13'], color=(0.55, 0.55, 0.55))
axs[0, 0].plot(data['16'], data['18'], color=(0.75, 0.75, 0.75))
axs[0, 0].plot(data['21'], data['23'], color=(0.9, 0.9, 0.9))
#axs[0, 0].set_title('Loading')
axs[0, 0].set(xlabel='$\epsilon$ (%)',ylabel='Loading factor (%)')
axs[0, 0].set_xlim([0, 2.5])

axs[0, 1].plot(data['2'], data['3'], color=(0.0, 0.0, 0.0))
axs[0, 1].plot(data['7'], data['8'], color=(0.3, 0.3, 0.3))
axs[0, 1].plot(data['12'], data['13'], color=(0.55, 0.55, 0.55))
axs[0, 1].plot(data['17'], data['18'], color=(0.75, 0.75, 0.75))
axs[0, 1].plot(data['22'], data['23'], color=(0.9, 0.9, 0.9))
#axs[0, 1].set_title('Loading')
axs[0, 1].set(xlabel=r'$(ES_{\epsilon}-VaR_{\epsilon})\epsilon$ (\$)',ylabel='Loading factor (%)')
axs[0, 1].set_xlim([0, 30])

axs[1, 0].plot(data['1'], data['4'], color=(0.0, 0.0, 0.0))
axs[1, 0].plot(data['6'], data['9'], color=(0.3, 0.3, 0.3))
axs[1, 0].plot(data['11'], data['14'], color=(0.55, 0.55, 0.55))
axs[1, 0].plot(data['16'], data['19'], color=(0.75, 0.75, 0.75))
axs[1, 0].plot(data['21'], data['24'], color=(0.9, 0.9, 0.9))
#axs[1, 0].set_title('Coverage')
axs[1, 0].set(xlabel='$\epsilon$ (%)',ylabel='Coverage rate (%)')
axs[1, 0].set_xlim([0, 2.5])

axs[1, 1].plot(data['2'], data['4'], color=(0.0, 0.0, 0.0))
axs[1, 1].plot(data['7'], data['9'], color=(0.3, 0.3, 0.3))
axs[1, 1].plot(data['12'], data['14'], color=(0.55, 0.55, 0.55))
axs[1, 1].plot(data['17'], data['19'], color=(0.75, 0.75, 0.75))
axs[1, 1].plot(data['22'], data['24'], color=(0.9, 0.9, 0.9))
#axs[1, 1].set_title('Coverage')
axs[1, 1].set(xlabel=r'$(ES_{\epsilon}-VaR_{\epsilon})\epsilon$ (\$)',ylabel='Coverage rate (%)')
axs[1, 1].set_xlim([0, 30])

axs[2, 0].plot(data['1'], data['5'], color=(0.0, 0.0, 0.0))
axs[2, 0].plot(data['6'], data['10'], color=(0.3, 0.3, 0.3))
axs[2, 0].plot(data['11'], data['15'], color=(0.55, 0.55, 0.55))
axs[2, 0].plot(data['16'], data['20'], color=(0.75, 0.75, 0.75))
axs[2, 0].plot(data['21'], data['25'], color=(0.9, 0.9, 0.9))
#axs[2, 0].set_title('Welfare')
axs[2, 0].set(xlabel='$\epsilon$ (%)',ylabel='Relative welfare gain (%)')
axs[2, 0].set_xlim([0, 2.5])

axs[2, 1].plot(data['2'], data['5'], color=(0.0, 0.0, 0.0))
axs[2, 1].plot(data['7'], data['10'], color=(0.3, 0.3, 0.3))
axs[2, 1].plot(data['12'], data['15'], color=(0.55, 0.55, 0.55))
axs[2, 1].plot(data['17'], data['20'], color=(0.75, 0.75, 0.75))
axs[2, 1].plot(data['22'], data['25'], color=(0.9, 0.9, 0.9))
#axs[2, 1].set_title('Welfare')
axs[2, 1].set(xlabel=r'$(ES_{\epsilon}-VaR_{\epsilon})\epsilon$ (\$)',ylabel='Relative welfare gain (%)')
axs[2, 1].set_xlim([0, 30])

for ax in axs.flat:
    ax.label_outer();
